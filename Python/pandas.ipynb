# %%
import pd as pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d001e6b1a3c9> in <module>
# ----> 1 import pd as pandas
#
# ModuleNotFoundError: No module named 'pd'

# %%
import pandas as pd

# %%
list=[12,23,30]
pd.Series(data=list)
# Out:
# 0    12
# 1    23
# 2    30
# dtype: int64

# %%
label=['x','y','z']
pd.Series(data=list,index=label)
# Out:
# x    12
# y    23
# z    30
# dtype: int64

# %%
array=[1,2,3]
pd.Series(data=array,index=label)
# Out:
# x    1
# y    2
# z    3
# dtype: int64

# %%
colors = pd.Series(data=[1,2,3,4],index=['red','green','blue','yellow'])

# %%
colors
# Out:
# red       1
# green     2
# blue      3
# yellow    4
# dtype: int64

# %%
colors[1]
# Out:
# 2

# %%
colors['red']
# Out:
# 1

# %%
colors1 = pd.Series(data=[1,2,3,4],index=['red','green','blue','black'])

# %%
colors+colors1
# Out:
# black     NaN
# blue      6.0
# green     4.0
# red       2.0
# yellow    NaN
# dtype: float64

# %%
dataframe=pd.DataFrame
